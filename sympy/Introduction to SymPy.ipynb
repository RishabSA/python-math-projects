# %%
import sympy as sp
import math

# %%
sp.sqrt(2) # Symbolic
# Out:
# sqrt(2)

# %%
sp.sqrt(2) ** 2 # Symbolic
# Out:
# 2

# %%
math.sqrt(2) # Numeric

# %%
math.sqrt(2) ** 2 # Numeric
# Out:
# 2.0000000000000004
